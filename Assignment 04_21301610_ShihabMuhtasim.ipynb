# %% [markdown]
# **Name: Shihab Muhtasim**
#
# **ID: 21301610**
#
# **SEC: 10**
#
# **ASSIGNMENT 4**

# %%
#1
class Calculator:
    def __init__(self):
        print("Let’s Calculate!")
    def add (self,num1,num2):
        return (num1+num2)
    def substract (self,num1,num2):
        return (num1-num2)
    def multiply (self,num1,num2):
        return num1*num2
    def divide (self,num1,num2):
        return num1/num2
        
val_1= int(input("Enter your value: "))
operator= input("Enter your operator: ")
val_2= int(input("Enter your value: ")) 

obj1=Calculator()
if operator=="+":
    result= obj1.add(val_1,val_2)
elif operator=="-":
    result= obj1.substract(val_1,val_2)
elif operator=="*":
    result= obj1.multiply(val_1,val_2)
elif operator=="/":
    result= obj1.divide(val_1,val_2)
print('Value 1:',val_1)
print('Operator:',operator)
print('Value 2:',val_2)
print("Result:",result)
# Out:
# Enter your value: 5
# Enter your operator: +
# Enter your value: 1
# Let’s Calculate!
# Value 1: 5
# Operator: +
# Value 2: 1
# Result: 6

# %%
#2
class Customer:
    def __init__(self,name):
        self.name=name
    def greet(self,name_2=None):
        if name_2==None:
            print("Hello!")
        else:
            print(f"Hello,{name_2}!")
    def purchase(self,*items):
        print(f'{self.name}, you purchased {len(items)} item(s):')
        for elem in items:
            print(elem)

customer_1 = Customer("Sam")
customer_1.greet()
customer_1.purchase("chips", "chocolate", "orange juice")
print("-----------------------------")
customer_2 = Customer("David")
customer_2.greet("David")
customer_2.purchase("orange juice")
# Out:
# Hello!
# Sam, you purchased 3 item(s):
# chips
# chocolate
# orange juice
# -----------------------------
# Hello,David!
# David, you purchased 1 item(s):
# orange juice

# %%
#3
class Panda:
    def __init__(self,name,gender,age):
        self.name=name
        self.gender=gender
        self.age=age
    def sleep(self,time=None):
        self.time=time
        if time==None:
            return f"{self.name}'s duration is unknown thus should have only bamboo leaves"
        elif 6<=time<=8:
            return f'{self.name} sleeps {self.time} hours daily and should have Eggplant & Tofu'
        elif 3<=time<=5:
            return f'{self.name} sleeps {self.time} hours daily and should have Mixed Veggies'
        elif 9<=time<=11:
            return f'{self.name} sleeps {self.time} hours daily and should have Broccoli Chicken'
panda1 = Panda("Kunfu","Male", 5)
panda2=Panda("Pan Pan","Female",3)
panda3=Panda("Ming Ming","Female",8)
print("{} is a {} Panda Bear who is {} years old".format(panda1.name,panda1.gender,panda1.age))
print("{} is a {} Panda Bear who is {} years old".format(panda2.name,panda2.gender,panda2.age))
print("{} is a {} Panda Bear who is {} years old".format(panda3.name,panda3.gender,panda3.age))
print("===========================")
print(panda2.sleep(10))
print(panda1.sleep(4))
print(panda3.sleep())
# Out:
# Kunfu is a Male Panda Bear who is 5 years old
# Pan Pan is a Female Panda Bear who is 3 years old
# Ming Ming is a Female Panda Bear who is 8 years old
# ...
# Pan Pan sleeps 10 hours daily and should have Broccoli Chicken
# Kunfu sleeps 4 hours daily and should have Mixed Veggies
# Ming Ming's duration is unknown thus should have only bamboo leaves

# %%
#4
class Cat:
    def __init__(self, colour='white', act='sitting'):
        self.colour=colour
        self.act=act
    def printCat(self):
        if self.colour=='white' and self.act=='sitting':
            print(f'{self.colour} cat is {self.act}')
        elif self.colour!='white' and self.act=='sitting':
            print(f'{self.colour} cat is {self.act}')
        else:
            print(f'{self.colour} cat is {self.act}')
    def changeColor(self, new_col):
        self.colour=new_col
        
c1 = Cat()
c2 = Cat("Black")
c3 = Cat("Brown", "jumping")
c4 = Cat("Red", "purring")
c1.printCat()
c2.printCat()
c3.printCat()
c4.printCat()
c1.changeColor("Blue")
c3.changeColor("Purple")
c1.printCat()
c3.printCat()
# Out:
# white cat is sitting
# Black cat is sitting
# Brown cat is jumping
# Red cat is purring
# Blue cat is sitting
# Purple cat is jumping

# %%
#5
class Student:
    def __init__(self,name="default"):
        self.name=name
    def quizcalc(self, *marks):
        total=0
        for mark in marks:
            total+=mark
        self.mark=(total/3)
    def printdetail(self):
        if self.name== "default":
            print(f'Hello {self.name} student')
        else:
            print(f'Hello {self.name}')
        print(f'Your average quiz score is {self.mark}')
s1 = Student()
s1.quizcalc(10)
print('--------------------------------')
s1.printdetail()
s2 = Student('Harry')
s2.quizcalc(10,8)
print('--------------------------------')
s2.printdetail()
s3 = Student('Hermione')
s3.quizcalc(10,9,10)
print('--------------------------------')
s3.printdetail()
# Out:
# --------------------------------
# Hello default student
# Your average quiz score is 3.3333333333333335
# --------------------------------
# Hello Harry
# Your average quiz score is 6.0
# --------------------------------
# Hello Hermione
# Your average quiz score is 9.666666666666666

# %%
#6
class Vehicle:
    def __init__(self,val_x=0,val_y=0):
        self.val_x=val_x
        self.val_y=val_y
    def moveUp(self):
        self.val_y=self.val_y+1
    def moveLeft(self):
        self.val_x=self.val_x-1
    def moveDown(self):
        self.val_y=self.val_y-1
    def moveRight(self):
        self.val_x=self.val_x+1
    def print_position(self):
        print((self.val_x,self.val_y))
        
car = Vehicle()
car.print_position()
car.moveUp()
car.print_position()
car.moveLeft()
car.print_position()
car.moveDown()
car.print_position()
car.moveRight()
# Out:
# (0, 0)
# (0, 1)
# (-1, 1)
# (-1, 0)

# %%
#7
class Programmer:
    def __init__(self,name,language,exp):
        self.name=name
        self.language=language
        self.exp=exp
        print("Horray! A new programmer is born")
    def printDetails(self):
        print('Name:', self.name)
        print('Language: ', self.language)
        print('Experience: ', self.exp,'years.')
    def addExp(self,num):
        self.exp+=num
        print(f'Updating experience of {self.name}')

p1 = Programmer("Ethen Hunt", "Java", 10)
p1.printDetails()
print('--------------------------')
p2 = Programmer("James Bond", "C++", 7)
p2.printDetails()
print('--------------------------')
p3 = Programmer("Jon Snow", "Python", 4)
p3.printDetails()
p3.addExp(5)
p3.printDetails()
# Out:
# Horray! A new programmer is born
# Name: Ethen Hunt
# Language:  Java
# Experience:  10 years.
# --------------------------
# Horray! A new programmer is born
# Name: James Bond
# Language:  C++
# Experience:  7 years.
# --------------------------
# Horray! A new programmer is born
# Name: Jon Snow
# Language:  Python
# Experience:  4 years.
# Updating experience of Jon Snow
# Name: Jon Snow
# Language:  Python
# Experience:  9 years.

# %%
#9
class Patient:
    def __init__(self,name,age):
        self.name=name
        self.age=age
    def add_Symptom(self,*symp):
        self.symptom=symp
    def printPatientDetail(self):
        print(f'Name: {self.name}')
        print(f'Age: {self.age}')
        print("Symptomps: ",end="")
        for index in range (len(self.symptom)):
            if index==len(self.symptom)-1:
                print(f'{self.symptom[index]}')
            else:
                print(f'{self.symptom[index]}, ',end="")
        print()

p1 = Patient('Thomas', 23)
p1.add_Symptom('Headache')
p2 = Patient('Carol', 20)
p2.add_Symptom('Vomiting', 'Coughing')
p3 = Patient('Mike', 25)
p3.add_Symptom('Fever', 'Headache', 'Coughing')
print("=========================")
p1.printPatientDetail()
print("=========================")
p2.printPatientDetail()
print("=========================")
p3.printPatientDetail()
print("=========================")
# Out:
# ...
# Name: Thomas
# Age: 23
# Symptomps: Headache
#
# ...
# Name: Carol
# Age: 20
# Symptomps: Vomiting, Coughing
#
# ...
# Name: Mike
# Age: 25
# Symptomps: Fever, Headache, Coughing
#
# ...

# %%
#10
class Avengers:
    def __init__(self,name,p):
        self.n=name
        self.p=p    
    def printAvengersDetail(self):        
        print(f'Name: {self.n}')
        print(f'Partner: {self.p}')        
        new_str=""
        for elem in self.powr:
            new_str+=f'{elem}, '
        final_str=new_str.rstrip(', ')
        print('Superpowers: ',final_str)
    def super_powers(self,*powr):
        self.powr=powr  
        
a1 = Avengers('Captain America', 'Bucky Barnes')
a1.super_powers('Stamina', 'Slowed ageing')
a2 = Avengers('Doctor Strange', 'Ancient One')
a2.super_powers('Mastery of magic')
a3 = Avengers('Iron Man', 'War Machine')
a3.super_powers('Genius level intellect', 'Scientist ')
print("=========================")
a1.printAvengersDetail()
print("=========================")
a2.printAvengersDetail()
print("=========================")
a3.printAvengersDetail()
print("=========================")
# Out:
# ...
# Name: Captain America
# Partner: Bucky Barnes
# Superpowers:  Stamina, Slowed ageing
# ...
# Name: Doctor Strange
# Partner: Ancient One
# Superpowers:  Mastery of magic
# ...
# Name: Iron Man
# Partner: War Machine
# Superpowers:  Genius level intellect, Scientist
# ...

# %%
#11
class Shinobi:
    def __init__(self,name,r):
        self.name=name
        self.r=r
        self.m=0
    def calSalary(self,m):
        self.m=m
    def changeRank(self,new):
        self.r=new
    def printInfo(self):
        print(f'Name: {self.name}')
        print(f'Rank: {self.r}')
        print(f'Number of mission: {self.m}')
        if self.r=='Genin':
            sal=self.m*50
        elif self.r=='Chunin':
            sal=self.m*100
        else:
            sal=self.m*500 
            
        print(f'Salary:{sal}')
            
naruto = Shinobi("Naruto", "Genin")
naruto.calSalary(5)
naruto.printInfo()
print('====================')
shikamaru = Shinobi('Shikamaru', "Genin")
shikamaru.printInfo()
shikamaru.changeRank("Chunin")
shikamaru.calSalary(10)
shikamaru.printInfo()
print('====================')
neiji = Shinobi("Neiji", "Jonin")
neiji.calSalary(5)
neiji.printInfo()
# Out:
# Name: Naruto
# Rank: Genin
# Number of mission: 5
# Salary:250
# ...
# Name: Shikamaru
# Rank: Genin
# Number of mission: 0
# Salary:0
# Name: Shikamaru
# Rank: Chunin
# Number of mission: 10
# Salary:1000
# ...
# Name: Neiji
# Rank: Jonin
# Number of mission: 5
# Salary:2500

# %%
#12
class ParcelKoro:
    def __init__(self,name='No name set',w=0):
        self.name=name
        self.w=w
    def printDetails(self):
        print('Customer Name:',self.name)
        print('Product Weight:',self.w)
        print('Total fee:',self.bill)
    def calculateFee(self,location=None):
        if self.w==0:
            bill=0
        else:
            if location==None:
                x=50
            else:
                x=100
                bill=self.w*20+x                            
        self.bill=bill
print("**********************")
p1 = ParcelKoro()
p1.calculateFee()
p1.printDetails()
print("**********************")
p2 = ParcelKoro('Bob The Builder')
p2.calculateFee()
p2.printDetails()
print("----------------------------")
p2.product_weight = 15
p2.calculateFee()
p2.printDetails()
print("**********************")
p3 = ParcelKoro('Dora The Explorer', 10)
p3.calculateFee('Dhanmondi')
p3.printDetails()
# Out:
# **********************
# Customer Name: No name set
# Product Weight: 0
# Total fee: 0
# **********************
# Customer Name: Bob The Builder
# Product Weight: 0
# Total fee: 0
# ----------------------------
# Customer Name: Bob The Builder
# Product Weight: 0
# Total fee: 0
# **********************
# Customer Name: Dora The Explorer
# Product Weight: 10
# Total fee: 300

# %%
#13
class Batsman:
    def __init__(self,*info):
        if len(info)==2:
            self.name='New Batsman'
            self.score=info[0]
            self.ball=info[1]
        elif len(info)==3:
            self.name=info[0]
            self.score=info[1]
            self.ball=info[2]            
    def setName(self,name):
        self.name=name
    def  printCareerStatistics(self):
        print("Name:",self.name)
        print("Runs Scored:",self.score,end=", ")
        print("Balls Faced:",self.ball) 
    def battingStrikeRate(self):
        strike_rate=(self.score/self.ball)*100
        return strike_rate 
        
b1 = Batsman(6101, 7380)
b1.printCareerStatistics()
print("============================")
b2 = Batsman("Liton Das", 678, 773)
b2.printCareerStatistics()
print("----------------------------")
print(b2.battingStrikeRate())
print("============================")
b1.setName("Shakib Al Hasan")
b1.printCareerStatistics()
print("----------------------------")
print(b1.battingStrikeRate())
# Out:
# Name: New Batsman
# Runs Scored: 6101, Balls Faced: 7380
# ...
# Name: Liton Das
# Runs Scored: 678, Balls Faced: 773
# ----------------------------
# 87.71021992238033
# ...
# Name: Shakib Al Hasan
# Runs Scored: 6101, Balls Faced: 7380
# ----------------------------
# 82.66937669376694

# %%
#14
class EPL_Team:
    def __init__(self,name,song="No Slogan",head=0):
        self.name=name
        self.song=song
        self.head=0
    def increaseTitle(self):
        self.head+=1
    def showClubInfo(self):
        info="Name: "+self.name+"\nSong:"+self.song+"\nTotal No of title:"+str(self.head)
        return info
    
    def changeSong(self,new_song):
        self.song=new_song

manu = EPL_Team('Manchester United', 'Glory Glory Man United')
chelsea = EPL_Team('Chelsea')
print('===================')
print(manu.showClubInfo())
print('##################')
manu.increaseTitle()
print(manu.showClubInfo())
print('===================')
print(chelsea.showClubInfo())
chelsea.changeSong('Keep the blue flag flying high')
print(chelsea.showClubInfo())
# Out:
# ...
# Name: Manchester United
# Song:Glory Glory Man United
# Total No of title:0
# ##################
# Name: Manchester United
# Song:Glory Glory Man United
# Total No of title:1
# ...
# Name: Chelsea
# Song:No Slogan
# Total No of title:0
# Name: Chelsea
# Song:Keep the blue flag flying high
# Total No of title:0

# %%
#task-15
class Account:
    def __init__(self,*info):
        if len(info)==0:
            self.name="Default Account"
            self.balance=0.0
        elif len(info)==1:
            self.name=info[0]
            self.balance=0.0
        else:
            self.name=info[0]
            self.balance=info[1]
    def withdraw(self,amount):
        v=self.balance-amount
        if v<=3070:
            print("Sorry, Withdraw unsuccessful!The account balance after deducting withdraw amount is equal to or less than minimum.")
        else:
            self.balance=v
            print("Withdraw successful! New balance is:",self.balance)
    def details(self):
        return f'{self.name}\n{self.balance}'
a1 = Account()
print(a1.details())
print("------------------------")
a1.name = "Oliver"
a1.balance = 10000.0
print(a1.details())
print("------------------------")
a2 = Account("Liam")
print(a2.details())
print("------------------------")
a3 = Account("Noah",400)
print(a3.details())
print("------------------------")
a1.withdraw(6930);
print("------------------------")
a2.withdraw(600);
print("------------------------")
a1.withdraw(6929)
# Out:
# Default Account
# 0.0
# ------------------------
# Oliver
# 10000.0
# ------------------------
# Liam
# 0.0
# ------------------------
# Noah
# 400
# ------------------------
# Sorry, Withdraw unsuccessful!The account balance after deducting withdraw amount is equal to or less than minimum.
# ------------------------
# Sorry, Withdraw unsuccessful!The account balance after deducting withdraw amount is equal to or less than minimum.
# ------------------------
# Withdraw successful! New balance is: 3071.0

# %%
#task-16
class Author:
    def __init__(self,name="Default",*book):
        self.name=name
        self.book_name=book
    def addBooks(self,*info):
        self.book_name=info
    def changeName(self,author):
        self.name=author
    def printDetails(self):
        print("Author Name:",self.name) 
        print("--------")
        print('List of Books:')
        for i in self.book_name:
            print(i)
auth1 = Author('Humayun Ahmed')
auth1.addBooks('Deyal','Megher Opor Bari')
auth1.printDetails()
print('===================')
auth2 = Author()
print(auth2.name)
auth2.changeName('Mario Puzo')
auth2.addBooks('The Godfather', 'Omerta', 'The Sicilian')
print('===================')
auth2.printDetails()
print('===================')
auth3 = Author('Paolo Coelho','The Alchemist', 'The Fifth Mountain')
auth3.printDetails()
# Out:
# Author Name: Humayun Ahmed
# --------
# List of Books:
# Deyal
# Megher Opor Bari
# ...
# Default
# ...
# Author Name: Mario Puzo
# --------
# List of Books:
# The Godfather
# Omerta
# The Sicilian
# ...
# Author Name: Paolo Coelho
# --------
# List of Books:
# The Alchemist
# The Fifth Mountain

# %%
#20 qqqqqq
class Author:
    def __init__(self,name=None):
        self.name=name
        self.dic={} 
        
    def addBook(self,book,catagory):       
        if self.name==None:
            print("NO")
        else:
            self.book=book
            self.catagory=catagory
            if self.catagory not in self.dic.keys():
                    self.dic[self.catagory]=[self.book]
            else:
                 self.dic[self.catagory].append(self.book)   
                    
    def setName(self,new):
        self.name=new  
        
    def printDetail(self):
        count=0
        for val in self.dic.values():
            count+=1            
        print(f'Number of Book(s): {count}' )
        print(f'Author Name:{self.name}' )
        for key,val in self.dic.items():
            temp=''
            for i in val:
                temp+=i
            print(f'{key}:{temp}') 
            
a1 = Author()
print("=================================")
a1.addBook("Ice", "Science Fiction")
print("=================================")
a1.setName("Anna Kavan")
a1.addBook("Ice", "Science Fiction")
a1.printDetail()
print("=================================")
a2 = Author("Humayun Ahmed")
a2.addBook("Onnobhubon", "Science Fiction")
a2.addBook("Megher Upor Bari", "Horror")
print("=================================")
a2.printDetail()
a2.addBook("Ireena", "Science Fiction")
print("=================================")
a2.printDetail()
print("=================================")
# Out:
# ...
# NO
# ...
# Number of Book(s): 1
# Author Name:Anna Kavan
# Science Fiction:Ice
# ...
# Number of Book(s): 2
# Author Name:Humayun Ahmed
# Science Fiction:Onnobhubon
# Horror:Megher Upor Bari
# ...
# Number of Book(s): 2
# Author Name:Humayun Ahmed
# Science Fiction:OnnobhubonIreena
# Horror:Megher Upor Bari
# ...

# %%
#19
class Hotel:
    def __init__(self,p_name,g_count=0,s_count=0,dic={}):
        self.p_name=p_name
        self.g_count=g_count
        self.s_count=s_count
        self.dic=dic
    def addStuff(self,name,age,phone_num='000'):
        self.name=name
        self.age=age
        self.phone_num=phone_num
        print(f'Staff With ID {self.s_count+1} is added')
        self.s_count+=1
        
    def getStuffById(self,id_no):
        self.id=id_no
        return f'Staff ID: {self.id}\nName: {self.name}\nAge: {self.age}\nPhone no.: {self.phone_num}'
         
    def addGuest(self,g_name,g_age,g_phone_num):    
        print(f'Guest With ID {self.g_count+1} is created')
        self.g_name=g_name
        self.g_age=g_age
        self.g_phone_num=g_phone_num
        self.dic[self.g_count+1]=[self.g_name,self.g_age,self.g_phone_num]
        self.g_count+=1
        print(self.dic)
       

    def getGuestById(self,g_id):
        self.g_id=g_id
        return f'Staff ID: {self.g_id}\nName: {self.g_name}\nAge: {self.g_age}\nPhone no.: {self.g_phone_num}'
        
    def allStaffs(self):
        print('All Staff:')
        print(f'Number of staff:{self.s_count}')
        print(f'Staff ID: {self.id} Name: {self.name} Age: {self.g_age} Phone no.: {self.phone_num}')
    def allGuest(self):
        print(f'All Guest:')
        print(f'Number of guest:{self.g_count}')
        for key,val in self.dic.items():
                print(f'Staff ID: {key} Name: {val[0]} Age: {val[1]} Phone no.: {val[2]}')
            
        
        

h = Hotel("Lakeshore")
h.addStuff( "Adam", 26)
print("=================================")
print(h.getStuffById(1))
print("=================================")
h.addGuest('Carol',35,'123')
print("=================================")
print(h.getGuestById(1))
print("=================================")
h.addGuest("Diana", 32, '431')
print("=================================")
print(h.getGuestById(2))
print("=================================")
h.allStaffs()
print("=================================")
h.allGuest()
# Out:
# Staff With ID 1 is added
# ...
# Staff ID: 1
# Name: Adam
# Age: 26
# Phone no.: 000
# ...
# Guest With ID 1 is created
# {1: ['Carol', 35, '123']}
# ...
# Staff ID: 1
# Name: Carol
# Age: 35
# Phone no.: 123
# ...
# Guest With ID 2 is created
# {1: ['Carol', 35, '123'], 2: ['Diana', 32, '431']}
# ...
# Staff ID: 2
# Name: Diana
# Age: 32
# Phone no.: 431
# ...
# All Staff:
# Number of staff:1
# Staff ID: 1 Name: Adam Age: 32 Phone no.: 000
# ...
# All Guest:
# Number of guest:2
# Staff ID: 1 Name: Carol Age: 35 Phone no.: 123
# Staff ID: 2 Name: Diana Age: 32 Phone no.: 431

# %%
#21
class Hospital:
    def __init__(self,name_h):
        self.dic_d={}
        self.dic_p={}
    def addDoctor(self,items_d):
        self.dic_d[items_d.id_no_d]=[items_d.name_d,items_d.specilist]
            
    def addPatient(self,items_p):
        self.dic_p[items_p.id_no_p]=[items_p.name_p,items_p.age,items_p.phn]
    def getDoctorByID(self,id_giv_d):
        for key,val in self.dic_d.items():
            if key == id_giv_d:
                x=f"Doctor's ID:{key}\nName: {val[0]}\nSpeciality:{val[1]}"
        return x
    def getPatientByID(self,id_giv_p):
        for key,val in self.dic_p.items():
            if key == id_giv_p:
                x=f"DPaitent's ID:{key}\nName: {val[0]}\nAge:{val[1]}\nPhone:{val[2]}"
        return x

class Patient:
    def __init__(self,id_no,intro,name,age,phn):
        self.id_no_p=id_no
        self.intro_p=intro
        self.name_p=name
        self.age=age
        self.phn=phn
class Doctor:
    def __init__(self,id_no_d,intro_d,name_d,specilist):
        self.id_no_d=id_no_d
        self.intro_d=intro_d
        self.name_d=name_d
        self.specilist=specilist



h = Hospital("Evercare")
d1 = Doctor("1d","Doctor", "Samar Kumar", "Neurologist")
h.addDoctor(d1)
print("=================================")
print(h.getDoctorByID("1d"))
print("=================================")
p1 = Patient("1p","Patient", "Kashem Ahmed", 35, 12345)
h.addPatient(p1)
print("=================================")
print(h.getPatientByID("1p"))
print("=================================")
p2 = Patient ("2p","Patient", "Tanina Haque", 26, 33456)
h.addPatient(p2)
print("=================================")
print(h.getPatientByID("2p"))
print("=================================")
# Out:
# ...
# Doctor's ID:1d
# Name: Samar Kumar
# Speciality:Neurologist
# ...
# DPaitent's ID:1p
# Name: Kashem Ahmed
# Age:35
# Phone:12345
# ...
# DPaitent's ID:2p
# Name: Tanina Haque
# Age:26
# Phone:33456
# ...

# %%
#22
class Vaccine:
    def __init__(self,vname,place,time):
        self.vname=vname
        self.place=place
        self.time=time
        
class Person:
    def __init__(self,*args):
        if len(args)==3:
            self.pname=args[0]
            self.age=args[1]
            self.work=args[2]
        else:
            self.pname=args[0]
            self.age=args[1]
            self.work='General Citizen'
        self.count=0
                        
    def pushVaccine(self,item,dose='1st dose'):
        self.dose=dose
        if self.dose!='1st dose':
            if self.v_name!=item.vname:
                print(f'Sorry {self.pname}')
            else:
                print(f'{self.dose} done for {self.pname}')
                self.count+=1                
        else:
            self.v_name=item.vname
            self.time=item.time
            if self.age>=25:
                print(f'{self.dose} done for {self.pname}')
                self.count+=1
            else:
                print(f'sorry {self.pname} not age')
    def showDetail(self):
        if self.count==1:
            print(f'Name:{self.pname} Age: {self.age} Type: {self.work}')
            print(f'Vaccine name: {self.v_name}')
            print(f'1st dose: Given')
            print(f'2nd dose: Please come after {self.time} days')
        else:
            print(f'Name:{self.pname} Age: {self.age} Type: {self.work}')
            print(f'Vaccine name: {self.v_name}')
            print(f'1st dose: Given')
            print(f'2nd dose: Given')
        


astra = Vaccine("AstraZeneca", "UK", 60)
modr = Vaccine("Moderna", "UK", 30)
sin = Vaccine("Sinopharm", "China", 30)
p1 = Person("Bob", 21, "Student")
print("=================================")
p1.pushVaccine(astra)
print("=================================")
p1.showDetail()
print("=================================")
p1.pushVaccine(sin, "2nd Dose")
print("=================================")
p1.pushVaccine(astra, "2nd Dose")
print("=================================")
p1.showDetail()
print("=================================")
p2 = Person("Carol", 23, "Actor")
print("=================================")
p2.pushVaccine(sin)
print("=================================")
p3 = Person("David", 34)
print("=================================")
p3.pushVaccine(modr)
print("=================================")
p3.showDetail()
print("=================================")
p3.pushVaccine(modr, "2nd Dose")
# Out:
# ...
# sorry Bob not age
# ...
# Name:Bob Age: 21 Type: Student
# Vaccine name: AstraZeneca
# 1st dose: Given
# 2nd dose: Given
# ...
# Sorry Bob
# ...
# 2nd Dose done for Bob
# ...
# Name:Bob Age: 21 Type: Student
# Vaccine name: AstraZeneca
# 1st dose: Given
# 2nd dose: Please come after 60 days
# ...
# sorry Carol not age
# ...
# 1st dose done for David
# ...
# Name:David Age: 34 Type: General Citizen
# Vaccine name: Moderna
# 1st dose: Given
# 2nd dose: Please come after 30 days
# ...
# 2nd Dose done for David
