# %%
#1
# Write your code here
class PlayerEarning:
    def __init__(self,name):
        self.name=name
    def calculateTotal(self,earn,goal=0):
        self.earn=earn
        if goal==0:
            self.bonus = 0
        else:
            if goal> 30:
                self.bonus = int(((5/100) * earn) + 10000)
            else:
                self.bonus = int((5/100) * earn)
        self.total=earn+self.bonus
    def printDetails(self):
        print(f"Player Name: {self.name}\nPlayer Season Earning without bonus: {self.earn}\nBonus: {self.bonus}\nPlayer Season Earning After Bonus: {self.total}")

print("**********************")
player1 = PlayerEarning('Buffon')
player1.calculateTotal(250000)
player1.printDetails()

print("\n**********************")
player2 = PlayerEarning('Dybala')
player2.calculateTotal(250000, 31)
player2.printDetails()

print("\n**********************")
player3 = PlayerEarning('Cuadrado')
player3.calculateTotal(250000, 20)
player3.printDetails()
# Out:
# **********************
# Player Name: Buffon
# Player Season Earning without bonus: 250000
# Bonus: 0
# Player Season Earning After Bonus: 250000
#
# **********************
# Player Name: Dybala
# Player Season Earning without bonus: 250000
# Bonus: 22500
# Player Season Earning After Bonus: 272500
#
# **********************
# Player Name: Cuadrado
# Player Season Earning without bonus: 250000
# Bonus: 12500
# Player Season Earning After Bonus: 262500

# %%
#2 problem line 13,23
class myList:
    def __init__(self,*nums):
        self.sum=0
        self.store=[]
        for i in nums:
            self.sum+=i
            self.store.append(i)
    def merge(self,*new):
        for i in new:
            self.sum+=i
            self.store.append(i)
    def Sum(self):
        print('sum',self.sum)
    def average(self):
        if len(self.store)==0:
            print('average:',0)
        else:
            print('average:',self.sum/len(self.store))


l1 =  myList(2,3,4,5,6) #you might need a list inside your class to store the values
l1.Sum()
l1.merge(4,5,9)
l1.Sum()                                                             
l1.average()
print('-----------------------------')
l2 =  myList()
l2.average()
l2.merge(1,2,4,8)
l2.Sum()
# Out:
# sum 20
# sum 38
# average: 4.75
# -----------------------------
# average: 0
# sum 15

# %%
#5
# Write your codes here.
class  Smartphone:
    def __init__(self,name='None'):
        self.name=name
        self.dic={}
    def setName(self,name):
        self.name=name
    def addFeature(self,product,model):
        if self.name=='None':
            print("Feature can not be added without phone name")
        else:
            if product not in self.dic.keys():
                self.dic[product]=[model]
            else:
                self.dic[product].append(model)
    def printDetail(self):
        print(f"Phone Name:{self.name}")
        for key,val in self.dic.items():
            ans=''
            for i in val:
                if key not in ans:
                    ans+=f'{key}:{i},'
                else:
                    ans+=f' {i},'
            final=ans.rstrip(',')
            print(final)
    
# Do not change the following lines of code.
s1 = Smartphone()
print("=================================")
s1.addFeature('Display', '6.1 inch')
print("=================================")
s1.setName('Samsung Note 20')
s1.addFeature('Display',' 6.1 inch')
s1.printDetail()
print("=================================")
s2 = Smartphone('Iphone 12 Pro')
s2.addFeature('Display', '6.2 inch')
s2.addFeature('Ram', '6 GB')
print('=================================')
s2.printDetail()
s2.addFeature('Display', 'Amoled panel')
s2.addFeature('Ram', 'DDR5')
print("=================================")
s2.printDetail()
print("=================================")
# Out:
# ...
# Feature can not be added without phone name
# ...
# Phone Name:Samsung Note 20
# Display: 6.1 inch
# ...
# Phone Name:Iphone 12 Pro
# Display:6.2 inch
# Ram:6 GB
# ...
# Phone Name:Iphone 12 Pro
# Display:6.2 inch, Amoled panel
# Ram:6 GB, DDR5
# ...

# %%
# Write Your Code Here
class Student:
    student_count=0
    cse_student=0
    bba_student=0
    def __init__(self,name,dept):
        self.name=name
        self.dept=dept
        Student.student_count+=1
        if dept=='CSE':
            Student.cse_student+=1
            self.dept_count=Student.cse_student
        else:
            Student.bba_student+=1
            self.dept_count=Student.bba_student
        print(f"Creating Student Number: {Student.student_count}")
        
    def individualInfo(self):
        print(f"{self.name} is from {self.dept} department.\nSerial of Naruto among all students' is: {Student.student_count}\nSerial of Naruto in {self.dept} department is: {self.dept_count}")
    def totalInfo(self):
        print(f"Total Number of Student: {Student.student_count}\nTotal Number of CSE Student: {Student.cse_student}\nTotal Number of BBA Student: {Student.bba_student}")

s1 = Student("Naruto", "CSE")
print('----------------------')
s1.individualInfo()
print('#############################')
s1.totalInfo()
print('============================')
 
s2 = Student("Sakura", "BBA")
print('----------------------')
s2.individualInfo()
print('#############################')
s2.totalInfo()
print('============================')
 
s3 = Student("Shikamaru", "CSE")
print('----------------------')
s3.individualInfo()
print('#############################')
s3.totalInfo()
print('============================')
 
s4 = Student("Deidara", "BBA")
print('----------------------')
s4.individualInfo()
print('#############################')
s4.totalInfo()
# Out:
# Creating Student Number: 1
# ----------------------
# Naruto is from CSE department.
# Serial of Naruto among all students' is: 1
# Serial of Naruto in CSE department is: 1
# #############################
# Total Number of Student: 1
# Total Number of CSE Student: 1
# Total Number of BBA Student: 0
# ...
# Creating Student Number: 2
# ----------------------
# Sakura is from BBA department.
# Serial of Naruto among all students' is: 2
# Serial of Naruto in BBA department is: 1
# #############################
# Total Number of Student: 2
# Total Number of CSE Student: 1
# Total Number of BBA Student: 1
# ...
# Creating Student Number: 3
# ----------------------
# Shikamaru is from CSE department.
# Serial of Naruto among all students' is: 3
# Serial of Naruto in CSE department is: 2
# #############################
# Total Number of Student: 3
# Total Number of CSE Student: 2
# Total Number of BBA Student: 1
# ...
# Creating Student Number: 4
# ----------------------
# Deidara is from BBA department.
# ...

# %%
#7 problemxxx
class book:
    def __init__(self, name):
        self.name = name
        self.genre='biography'
    def review(self):
         print('This book is just out of the world,mind-blowing!')

# Write your code here        
class fiction(book):
    def __init__(self,name,genre):
        super().__init__(name)
        self.genre=genre
    def review(self):
        store=f"{self.name} 'which is a' {self.genre} "
        super().review().replace('This book',store)
        super().review()
        
class nonfiction(book):
    def __init__(self,name):
        super().__init__(name)
        
    def review(self):
        store=f"{self.name} 'which is a' {self.genre}"
        super().review().replace('This book',store)
        super().review()
        
b1 = fiction('The Shining','Psychological horror')
b2 = nonfiction('A Beautiful Mind')
b1.review()
print('=========================')
b2.review()
print('=========================')
# Out:
# This book is just out of the world,mind-blowing!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-58-b2a37389653a> in <module>
#      28 b1 = fiction('The Shining','Psychological horror')
#      29 b2 = nonfiction('A Beautiful Mind')
# ---> 30 b1.review()
#      31 print('=========================')
#      32 b2.review()
#
# <ipython-input-58-b2a37389653a> in review(self)
#      14     def review(self):
#      15         store=f"{self.name} 'which is a' {self.genre} "
# ---> 16         super().review().replace('This book',store)
#      17         super().review()
#      18
#
# AttributeError: 'NoneType' object has no attribute 'replace'

# %%
a='abcd'
print(a.replace('b','x'))
# Out:
# axcd

# %%
#7
class book:
    def __init__(self, name):
        self.name = name
        self.genre='biography'
    def review(self):
         print('This book is just out of the world,mind-blowing!')

# Write your code here        
class fiction(book):
    def __init__(self,name,genre):
        super().__init__(name)
        self.genre=genre
    def review(self):
        store=f"{self.name} which is a {self.genre} is just out of the world,mind-blowing!"
        print(store)

class nonfiction(book):
    def __init__(self,name):
        super().__init__(name)
    def review(self):
        store=f"{self.name} which is a {self.genre} is just out of the world,mind-blowing!"
        print(store)

b1 = fiction('The Shining','Psychological horror')
b2 = nonfiction('A Beautiful Mind')
b1.review()
print('=========================')
b2.review()
print('=========================')
# Out:
# The Shining which is a Psychological horror is just out of the world,mind-blowing!
# ...
# A Beautiful Mind which is a biography is just out of the world,mind-blowing!
# ...

# %%
#8
class Processor:
    def __init__(self, model, thread, core):
        self.model = model
        self.core = core
        self.thread = thread
    def getInfo(self):
        return 'Model:'+self.model+ '\nCores:'+str(self.core)+ '\nThreads:'+ str(self.thread) 
# Write your code here
class Intel(Processor):
    def __init__(self,model, thread, core,price):
        super().__init__(model, thread, core)
        self.price=price
    def getInfo(self):
        print(f"{super().getInfo()}\nPrice: {self.price}")
class AMD(Processor):
    def __init__(self,model, thread, core,price):
        super().__init__(model, thread, core)
        self.price=price
    def getInfo(self):
        print(f"{super().getInfo()}\nPrice: {self.price}")
p1 = Intel("Intel i5 10th Gen",6,12,17000)
p2 = AMD("Ryzen 5 3500X",6,6,13800)
p3 = AMD("Ryzen 5 3600",6,12,16900)
print('======================')
p1.getInfo()
print('======================')
p2.getInfo()
print('======================')
p3.getInfo()
# Out:
# ...
# Model:Intel i5 10th Gen
# Cores:12
# Threads:6
# Price: 17000
# ...
# Model:Ryzen 5 3500X
# Cores:6
# Threads:6
# Price: 13800
# ...
# Model:Ryzen 5 3600
# Cores:12
# Threads:6
# Price: 16900

# %%
#9
class Fruit:
    Total_order=0
    
    def __init__(self, Order_ID, weight):
        self.Order_ID=Order_ID
        self.weight=weight
        Fruit.Total_order=Fruit.Total_order+1
    
    def __str__(self):
        return self.Order_ID+", Weight: "+str(self.weight)
#write your code here
class Mango(Fruit):
    def __init__(self,Order_ID, weight,variety,unit_price):
        super().__init__(Order_ID, weight)
        self.variety=variety
        self.price=unit_price* self.weight
    def __add__(self,other):
        add= self.price+other.price
        return f"The total Price of the orders are: {add}"
    def __str__(self):  
        return f"{super().__str__()},Variety: {self.variety}, Total Price: {self.price}"
     
class JackFruit(Fruit):
    def __init__(self,Order_ID, weight,unit_price):
        super().__init__(Order_ID, weight)
        self.price=unit_price* self.weight
    def __add__(self,other):
        add= self.price+other.price
        return f"The total Price of the orders are: {add}"
    def __str__(self):
        super().__str__()
        return f"{super().__str__()},Total Price: {self.price}"
    
m1=Mango("Order Id 1", 5,"GopalVog",250)
print(m1)
m2=Mango("Order Id 2", 5,"HariVanga", 230)
print(m2) 
j1=JackFruit("Order Id 3", 5,250)
print(j1)
j2=JackFruit("Order Id 4", 4,210)
print(j2)
print("Total number of Orders: "+str(Fruit.Total_order))
print("==================")
print(m1+m2)
print("==================")
print(j1+j2)
# Out:
# Order Id 1, Weight: 5,Variety: GopalVog, Total Price: 1250
# Order Id 2, Weight: 5,Variety: HariVanga, Total Price: 1150
# Order Id 3, Weight: 5,Total Price: 1250
# Order Id 4, Weight: 4,Total Price: 840
# Total number of Orders: 4
# ...
# The total Price of the orders are: 2400
# ...
# The total Price of the orders are: 2090

# %%
#10
class Student:
    def __init__(self,name,ID):
        self.name = name
        self.ID = ID
    def Details(self):
        return "Name: "+self.name+"\n"+"ID: "+self.ID+"\n"
#Write your code here
class CSEStudent(Student):
    def __init__(self,name,ID,sem):
        super().__init__(name,ID)
        self.sem=sem
    def Details(self):
        return f"Name: {self.name}\nID: {self.ID}\nCurrent semester: {self.sem}"
    def addCourseWithMarks(self,*args):
        self.dic={}
        for i in range(0,len(args),2):
            cg=0
            if args[i+1]>=85:
                cg=4.0
            elif 80<=args[i+1]<=84:
                cg=3.3
            elif 70<=args[i+1]<=79:
                cg=3.0
            elif 65<=args[i+1]<=69:
                cg=2.3
            elif 57<=args[i+1]<=64:
                cg=2.0
            elif 55<=args[i+1]<=56:
                cg=1.3
            elif 50<=args[i+1]<=54:
                cg=1.0
            elif 50>args[i+1]:
                cg=0.0
            self.dic[args[i]]=cg
    def showGPA(self):
        print(f"Carol has taken {len(self.dic)} courses.")
        total=0
        for key,val in self.dic.items():
            print(key,val)
            total+=val*3
        gpa=total/(len(self.dic)*3)
        shorted_gpa="{:.2f}".format(gpa)
        print(f"GPA of Carol is: {shorted_gpa}")

Bob = CSEStudent("Bob","20301018",'Fall 2020')
Carol = CSEStudent("Carol","16301814",'Fall 2020')
Anny = CSEStudent("Anny","18201234",'Fall 2020')
print("#########################")
print(Bob.Details())
print("#########################")
print(Carol.Details())
print("#########################")
print(Anny.Details())
print("#########################")
Bob.addCourseWithMarks("CSE111",83.5,"CSE230",73.0,"CSE260",92.5)
Carol.addCourseWithMarks("CSE470",62.5,"CSE422",69.0,"CSE460",76.5,"CSE461",87.0)
Anny.addCourseWithMarks("CSE340",45.5,"CSE321",95.0,"CSE370",91.0)
print("----------------------------")
Bob.showGPA()
print("----------------------------")
Carol.showGPA()
print("----------------------------")
Anny.showGPA()
# Out:
# #########################
# Name: Bob
# ID: 20301018
# Current semester: Fall 2020
# #########################
# Name: Carol
# ID: 16301814
# Current semester: Fall 2020
# #########################
# Name: Anny
# ID: 18201234
# Current semester: Fall 2020
# #########################
# ----------------------------
# Carol has taken 3 courses.
# CSE111 3.3
# CSE230 3.0
# CSE260 4.0
# GPA of Carol is: 3.43
# ----------------------------
# Carol has taken 4 courses.
# CSE470 2.0
# CSE422 2.3
# CSE460 3.0
# CSE461 4.0
# GPA of Carol is: 2.82
# ----------------------------
# Carol has taken 3 courses.
# CSE340 0.0
# CSE321 4.0
# CSE370 4.0
# GPA of Carol is: 2.67

# %%
#11
class Transport:
    total_traveller = 0
    
    def __init__(self, name, fare):
        self.name = name
        self.baseFare = fare
    
    def __str__(self):
        s =  'Name: '+self.name+", Base fare: "+str(self.baseFare)
        return s
class Bus(Transport):
    def __init__(self, name, fare):
        super().__init__(name, fare)
        Transport.total_traveller += 1
        print(f"Base-fare of {self.name} is {self.baseFare} Taka")
    def addPassengerWithBags(self,*args):
        self.dic={}
        for i in range(0,len(args),2):
            fare=0
            if args[i+1]<=2:
                fare+=self.baseFare
            elif 2<args[i+1]<=5:
                fare+=self.baseFare+60
            elif 5<args[i+1]:
                fare+=self.baseFare+120
            self.dic[args[i]]=fare
    def __str__(self):
        temp_1= f"{super().__str__()}\nTotal Passenger(s): {Transport.total_traveller}\nPassenger details:\n"
        for key,val in self.dic.items():
            temp_1+=f"Name: {key}, Fare: {val}\n"
        return temp_1
        
class Train(Transport):
# Write your codes here.
# Do not change the following lines of code.
t1 = Bus('Volvo', 950)
print("=================================")
t1.addPassengerWithBags('David', 6,  'Mike', 1, 'Carol', 3)
print("=================================")
print(t1)
print("=================================")
t2 = Train('Silk City', 850)
print("=================================")
t2.addPassengerWithBags('Bob', 2, 'Simon', 4)
print("=================================")
print(t2)
print("=================================")
print('Total Passengers in Transport: ', Transport.total_traveller )
# Out:
# Base-fare of Volvo is 950 Taka
# ...
# Name: Volvo, Base fare: 950
# Total Passenger(s): 1
# Passenger details:
# Name: David, Fare: 1070
# Name: Mike, Fare: 950
# Name: Carol, Fare: 1010
#
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-1d80f539807f> in <module>
#      40 print(t1)
#      41 print("=================================")
# ---> 42 t2 = Train('Silk City', 850)
#      43 print("=================================")
#      44 t2.addPassengerWithBags('Bob', 2, 'Simon', 4)
#
# NameError: name 'Train' is not defined

# %%
#12
class AppleProduct:
    def __init__(self, name, model, base_price):
        self.name = name
        self.model = model
        self.base_price = base_price
    def companyInfo(self):
        st = ("Company Name: Apple\nFouder: Steve Jobs, Steve Wozniak, Ronald Wayne\nCurrent CEO: Tim Cook\nAddress: Apple Inc, 2511 Laguna Blvd, Elk Grove, CA 95758, United States")    
        return st
    def feature(self):
        st = (f"Name: {self.name}\nProduct Model: {self.model}\nHardware Quality: Excellent Hardwares\nGuarantee/ Warranty: Apple Care")
        return st
    def __str__(self):
        print('This is apple product.')
    def calculatePrice(self):
        print('Total Price:', self.base_price)
# Write your codes here.
# Do not change the following lines of code.
class MacBookPro2020(AppleProduct):
    def __init__(self, name, model, ram,chip,tax):
        super().__init__(name, model,base_price=1299)
        self.ram=ram
        self.chip=chip
        self.tax=tax
    def calculatePrice(self):
        total_tax=(self.base_price*self.tax)/100
        print(f"Calculating Total Price:\nTotal Price: {self.base_price+total_tax}")
    def __str__(self):
        return f"{super().feature()}\nRAM: {self.ram}GB\nChip: {self.chip}\nCompany Details:\n{super().companyInfo()}"

        

    
    
m1 = MacBookPro2020('MacBook', 'MacBookPro2020', 8, 'M1', 10)
print(m1)
print('====================================')
m1.calculatePrice()
print('###################################')
iphone = iPhone12('iPhone', 'iPhone 12', 8, 'A14', 5)
print(iphone)
print('====================================')
iphone.calculatePrice()  
print('###################################')
print('Total Price of these two products: ',end='')
print('%.2f Dollars'%(m1 + iphone))
# Out:
# Name: MacBook
# Product Model: MacBookPro2020
# Hardware Quality: Excellent Hardwares
# Guarantee/ Warranty: Apple Care
# RAM: 8GB
# Chip: M1
# Company Details:
# Company Name: Apple
# Fouder: Steve Jobs, Steve Wozniak, Ronald Wayne
# Current CEO: Tim Cook
# Address: Apple Inc, 2511 Laguna Blvd, Elk Grove, CA 95758, United States
# ...
# Calculating Total Price:
# Total Price: 1428.9
# ###################################
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-5c992c04643c> in <module>
#      38 m1.calculatePrice()
#      39 print('###################################')
# ---> 40 iphone = iPhone12('iPhone', 'iPhone 12', 8, 'A14', 5)
#      41 print(iphone)
#      42 print('====================================')
#
# NameError: name 'iPhone12' is not defined

# %%
a="Total:",20
a+=5
print(a)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-83aa43a82291> in <module>
#       1 a="Total:",20
# ----> 2 a+=5
#       3 print(a)
#
# TypeError: can only concatenate tuple (not "int") to tuple

# %%
#13
class University:
    name  = "ABC University"
    numberOfStudents = 0
    admissionFee = 28000
    Library = 2000
    def __init__(self, n,i):
        self.stName = n
        self.stId = i
         
    def payment(self):
        return self.admissionFee + self.Library

    def __str__(self):
        return "Student Name: {}, ID: {}\nFee: {}".format(self.stName, self.stId, self.payment())
 
# Write your codes here.
# Do not change the following lines of code.

class CSE_dept(University):
    PerCreditFee = 6600
    SemesterFee =7700
    LabFee=2750
    def __init__(self,name,id,credit=6):
        super().__init__(name,id)
        University.numberOfStudents+=1
        self.credit=credit
        
    def payment(self):
        self.total=super().payment()+CSE_dept.SemesterFee+CSE_dept.LabFee+(CSE_dept.PerCreditFee*self.credit)
        return self.total
    def payment_details(self):
        print(f"DETAILS:\nAdmission Fee: {University.admissionFee}\nLibrary Fee: {University.Library}\nSemester Fee: {CSE_dept.SemesterFee}\nPer Credit Fee: {CSE_dept.PerCreditFee}\nNumber of credits: {self.credit}\nLab Fee: {CSE_dept.LabFee}")
    def __add__(self,other):
        rev=self.total+other.total
        return rev
    
class PHR_dept(University):
    PerCreditFee = 6600 
    SemesterFee =11000
    def __init__(self,name,id,credit=9):
        University.numberOfStudents+=1
        super().__init__(name,id)
        self.credit=credit
        
    def payment(self):
        self.total=super().payment()+PHR_dept.SemesterFee+(PHR_dept.PerCreditFee*self.credit)
        return self.total
    def payment_details(self):
        print(f"DETAILS:\nAdmission Fee: {University.admissionFee}\nLibrary Fee: {University.Library}\nSemester Fee: {self.SemesterFee}\nPer Credit Fee: {self.PerCreditFee}\nNumber of credits: {self.credit}")
    def __add__(self,other):
        rev=self.total+other.total
        return rev
    
    
c1 = CSE_dept("Mary","5678")  
print(c1)
c1.payment_details()
print("===========================")
p1 = PHR_dept("Simon","91011")  
print(p1)
p1.payment_details()
print("===========================")
c2 = CSE_dept("Adam","1234", 12)  
print(c2)
c2.payment_details()
print("===========================")
p2 = PHR_dept("David","121314", 15)  
print(p2)
p2.payment_details()
print("===========================")
print("Total Number of Students:", University.numberOfStudents)
print("Total University Revenue:", (c1 + c2) + (p1 + p2))
print("===========================")
print("Due to the pandemic, admission and library fees have been reduced for all departments. ")
University.admissionFee -= 1000
University.Library -= 100
print("The credit, semester and lab fees have been reduced for the CSE department. ")
CSE_dept.PerCreditFee -= 100
CSE_dept.SemesterFee -= 100
CSE_dept.LabFee -=100
print("The credit and semester fees have been reduced for the PHR department.\n ")
PHR_dept.PerCreditFee -= 100
PHR_dept.SemesterFee -= 1000
print(c1)
print(p1)
print(c2)
print(p2)
print("===========================")
print("Total Number of Students:", University.numberOfStudents)
print("Total University Revenue:", (c1 + c2) + (p1 + p2))
# Out:
# Student Name: Mary, ID: 5678
# Fee: 80050
# DETAILS:
# Admission Fee: 28000
# Library Fee: 2000
# Semester Fee: 7700
# Per Credit Fee: 6600
# Number of credits: 6
# Lab Fee: 2750
# ...
# Student Name: Simon, ID: 91011
# Fee: 100400
# DETAILS:
# Admission Fee: 28000
# Library Fee: 2000
# Semester Fee: 11000
# Per Credit Fee: 6600
# Number of credits: 9
# ...
# Student Name: Adam, ID: 1234
# Fee: 119650
# DETAILS:
# Admission Fee: 28000
# Library Fee: 2000
# Semester Fee: 7700
# Per Credit Fee: 6600
# Number of credits: 12
# Lab Fee: 2750
# ...
# Student Name: David, ID: 121314
# Fee: 140000
# DETAILS:
# Admission Fee: 28000
# Library Fee: 2000
# Semester Fee: 11000
# Per Credit Fee: 6600
# Number of credits: 15
# ...
# Total Number of Students: 4
# Total University Revenue: 440100
# ...
# Due to the pandemic, admission and library fees have been reduced for all departments.
# The credit, semester and lab fees have been reduced for the CSE department.
# ...

# %%
#14
class Library:
    Total_book = 1000
    borrow_data = {}
    
    def __init__(self,n,id):
        self.student_name = n
        self.student_id = id     
    
    def borrowbook(self):
        print("A book is borrowed!")
        
    def __str__(self):
        return "Library: XYZ"

#Write your code here
class Student(Library):
    string=''
    def __init__(self,n,id):  
        super().__init__(n,id)
        self.removal_list=[]
    def borrowbook(self,book,code="none"):
        self.book=book
        if book not in Library.borrow_data.keys():
            self.removal_list.append(book)
            Library.borrow_data[book]=[self.student_name]
            Library.Total_book-=1
            super().borrowbook()
            if code=="none":
                print(f"'{book}' book is borrowed by {self.student_name}({self.student_id}) ")
            else:
                print(f"'{book}' book with the unique id {code} is borrowed by {self.student_name}({self.student_id}) ")
        
            print(f'Number of books available for borrowing = {Library.Total_book}')
        else:
            print(f"Sorry {self.student_name} ! {book} book is borrowed by {Library.borrow_data[book]}")
        
        if Student.string=='':
            Student.string+=book
        else:
            Student.string+=', '+book
    def returnAllBooks(self):
        for key in self.removal_list:
            del  Library.borrow_data[key]
        print(f"All Books are returned by {self.student_name}")
        
        
    def __str__(self):
        return f"{super().__str__()}\nStudent Name: {self.student_name} ID: {self.student_id}\nBooks borrowed: {Student.string}"

        
            


s1 = Student("Alice",18101259)
s1.borrowbook("The Alchemist", "Hdw652")
print("===============")
print(s1)
print("===============")
print(Library.borrow_data)
print("===============")
s1.borrowbook("Wuthering Heights")
print("===============")
print(s1)
print("===============")
s2= Student("David",18141777)
s2.borrowbook("The Alchemist", "Hdw652")
print("===============")
s2.borrowbook("The Vampyre")
print("===============")
print(Library.borrow_data)
print("===============")
s1.returnAllBooks()
print("===============")
print(Library.borrow_data)
# Out:
# A book is borrowed!
# 'The Alchemist' book with the unique id Hdw652 is borrowed by Alice(18101259)
# Number of books available for borrowing = 999
# ...
# Library: XYZ
# Student Name: Alice ID: 18101259
# Books borrowed: The Alchemist
# ...
# {'The Alchemist': ['Alice']}
# ...
# A book is borrowed!
# 'Wuthering Heights' book is borrowed by Alice(18101259)
# Number of books available for borrowing = 998
# ...
# Library: XYZ
# Student Name: Alice ID: 18101259
# Books borrowed: The Alchemist, Wuthering Heights
# ...
# Sorry David ! The Alchemist book is borrowed by ['Alice']
# ...
# A book is borrowed!
# 'The Vampyre' book is borrowed by David(18141777)
# Number of books available for borrowing = 997
# ...
# {'The Alchemist': ['Alice'], 'Wuthering Heights': ['Alice'], 'The Vampyre': ['David']}
# ...
# All Books are returned by Alice
# ...
# {'The Vampyre': ['David']}

# %%
#15
class Player:
    database={}
    playerNo = 0
    def __init__(self,name,team,jerseyNo):
        self.name = name
        self.team = team
        self.jerseyNo = jerseyNo
    def __str__(self):
        return "Name:{}\nTeam:{}\nJersey No:{}".format(self.name,self.team,self.jerseyNo)

#Write your code here
class FootballPlayer(Player):
    def __init__(self,name,team,jerseyNo,goal,retire='Not yet retired'):
        super().__init__(name,team,jerseyNo)
        self.goal=goal
        self.retire=retire
        Player.playerNo+=1
        self.playerNo=Player.playerNo
        self.id_no=str(self.playerNo)
        temp=self.name.split(" ")
        for word in temp:
            self.id_no+=word[0]
        self.id_no+=str(self.jerseyNo)
        Player.database[self.id_no]=[self.name,self.team,self.jerseyNo,goal,retire]
    @classmethod
    def createPlayer(cls,name,team,jerseyNo,goal,retire):
        obj=cls(name,team,jerseyNo,goal,retire)
        return obj
    def __str__(self):
        return f"Player ID:{self.id_no}\n{super().__str__()}\nGoals Scored:{self.goal}\nRetirement date:{self.retire}"
        
           
print("Number of players:",Player.playerNo)
print("Player Database:",Player.database)
print("#################################")
p1 = FootballPlayer("Lionel Messi","Barcelona",10,231)
print("------Details of the player------")
print(p1)
print("#################################")
p2 = FootballPlayer("Cristiano Ronaldo","Juventus",7,215)
print("------Details of the player------")
print(p2)
print("#################################")
p3 = FootballPlayer.createPlayer("Miroslav Klose","Lazio",11, 71,"11 Aug,2014")
print("------Details of the player------")
print(p3)
print("#################################")
print("Number of players:",Player.playerNo)
print("Player Database:",Player.database)
# Out:
# Number of players: 0
# Player Database: {}
# #################################
# ------Details of the player------
# Player ID:1LM10
# Name:Lionel Messi
# Team:Barcelona
# Jersey No:10
# Goals Scored:231
# Retirement date:Not yet retired
# #################################
# ------Details of the player------
# Player ID:2CR7
# Name:Cristiano Ronaldo
# Team:Juventus
# Jersey No:7
# Goals Scored:215
# Retirement date:Not yet retired
# #################################
# ------Details of the player------
# Player ID:3MK11
# Name:Miroslav Klose
# Team:Lazio
# Jersey No:11
# Goals Scored:71
# Retirement date:11 Aug,2014
# #################################
# Number of players: 3
# Player Database: {'1LM10': ['Lionel Messi', 'Barcelona', 10, 231, 'Not yet retired'], '2CR7': ['Cristiano Ronaldo', 'Juventus', 7, 215, 'Not yet retired'], '3MK11': ['Miroslav Klose', 'Lazio', 11, 71, '11 Aug,2014']}

# %%
class CSEDepartment:
    
    total_student = 0

    def __init__(self, name, credit):
        
        self.name = name
        self.credit = credit

    def __str__(self):
        s =  'Program: '+self.name+", Credit hours: "+str(self.credit)
        return s

# Write your codes here.
# Do not change the following lines of code.
class CSEProgram(CSEDepartment):
    def __init__(self, name, credit):
        super().__init__(name, credit)
        print(f"{self.name} students need to complete {self.credit} credits")
    def addStudentWithCredits(self,*args):
        print(self.list)
        CSEDepartment.total_student+=len(args)//2
        for i in range(1,len(self.list),2):
            self.list[i]=self.credit-self.list[i]
    def  __str__(self):
        temp=''
        for i in range(0,len(self.list),2):
            temp+=f"Name: {self.list[i]}, Credit remaining: {self.list[i+1]}\n"
        return f"{super().__str__()}\nTotal students(s): {CSEDepartment.total_student}\nStudent details:\n{temp}" 
        
        
p1 = CSEProgram('CSE', 136)
print("=================================")
p1.addStudentWithCredits('Bob', 12,  'Carol', 18, 'Mike', 15)
print("=================================")
print(p1)
print("=================================")
p2 = CSProgram('CS', 124)
print("=================================")
p2.addStudentWithCredits('David', 12, 'Simon', 18)
print("=================================")
print(p2)
print("=================================")
print('Total Students in CSE Department: ', CSEDepartment.total_student)
# Out:
# CSE students need to complete 136 credits
# ...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-9dda2cb5626f> in <module>
#      32 p1 = CSEProgram('CSE', 136)
#      33 print("=================================")
# ---> 34 p1.addStudentWithCredits('Bob', 12,  'Carol', 18, 'Mike', 15)
#      35 print("=================================")
#      36 print(p1)
#
# <ipython-input-45-9dda2cb5626f> in addStudentWithCredits(self, *args)
#      19         print(f"{self.name} students need to complete {self.credit} credits")
#      20     def addStudentWithCredits(self,*args):
# ---> 21         print(self.list)
#      22         CSEDepartment.total_student+=len(args)//2
#      23         for i in range(1,len(self.list),2):
#
# AttributeError: 'CSEProgram' object has no attribute 'list'

# %%
#13
class University:
    name  = "ABC University"
    numberOfStudents = 0
    admissionFee = 28000
    Library = 2000
    def __init__(self, n,i):
        self.stName = n
        self.stId = i
         
    def payment(self):
        return self.admissionFee + self.Library

    def __str__(self):
        return "Student Name: {}, ID: {}\nFee: {}".format(self.stName, self.stId, self.payment())
 
# Write your codes here.
# Do not change the following lines of code.

class CSE_dept(University):
    PerCreditFee = 6600
    SemesterFee =7700
    LabFee=2750
    def __init__(self,name,id,credit=6):
        super().__init__(name,id)
        University.numberOfStudents+=1
        self.credit=credit
        
    def payment(self):
        self.total=super().payment()+CSE_dept.SemesterFee+CSE_dept.LabFee+(CSE_dept.PerCreditFee*self.credit)
        return self.total
    def payment_details(self):
        print(f"DETAILS:\nAdmission Fee: {University.admissionFee}\nLibrary Fee: {University.Library}\nSemester Fee: {CSE_dept.SemesterFee}\nPer Credit Fee: {CSE_dept.PerCreditFee}\nNumber of credits: {self.credit}\nLab Fee: {CSE_dept.LabFee}")
    def __add__(self,other):
        rev=self.total+other.total
        return rev
    
class PHR_dept(University):
    PerCreditFee = 6600 
    SemesterFee =11000
    def __init__(self,name,id,credit=9):
        University.numberOfStudents+=1
        super().__init__(name,id)
        self.credit=credit
        
    def payment(self):
        self.total=super().payment()+PHR_dept.SemesterFee+(PHR_dept.PerCreditFee*self.credit)
        return self.total
    def payment_details(self):
        print(f"DETAILS:\nAdmission Fee: {University.admissionFee}\nLibrary Fee: {University.Library}\nSemester Fee: {self.SemesterFee}\nPer Credit Fee: {self.PerCreditFee}\nNumber of credits: {self.credit}")
    def __add__(self,other):
        rev=self.total+other.total
        return rev
    
    
c1 = CSE_dept("Mary","5678")  
print(c1)
c1.payment_details()
print("===========================")
p1 = PHR_dept("Simon","91011")  
print(p1)
p1.payment_details()
print("===========================")
c2 = CSE_dept("Adam","1234", 12)  
print(c2)
c2.payment_details()
print("===========================")
p2 = PHR_dept("David","121314", 15)  
print(p2)
p2.payment_details()
print("===========================")
print("Total Number of Students:", University.numberOfStudents)
print("Total University Revenue:", (c1 + c2) + (p1 + p2)
print("===========================")
print("Due to the pandemic, admission and library fees have been reduced for all departments. ")
University.admissionFee -= 1000
University.Library -= 100
print("The credit, semester and lab fees have been reduced for the CSE department. ")
CSE_dept.PerCreditFee -= 100
CSE_dept.SemesterFee -= 100
CSE_dept.LabFee -=100
print("The credit and semester fees have been reduced for the PHR department.\n ")
PHR_dept.PerCreditFee -= 100
PHR_dept.SemesterFee -= 1000
print(c1)
print(p1)
print(c2)
print(p2)
print("===========================")
print("Total Number of Students:", University.numberOfStudents)
print("Total University Revenue:", (c1 + c2) + (p1 + p2))
# Out:
# Student Name: Mary, ID: 5678
# Fee: 80050
# DETAILS:
# Admission Fee: 28000
# Library Fee: 2000
# Semester Fee: 7700
# Per Credit Fee: 6600
# Number of credits: 6
# Lab Fee: 2750
# ...
# Student Name: Simon, ID: 91011
# Fee: 100400
# DETAILS:
# Admission Fee: 28000
# Library Fee: 2000
# Semester Fee: 11000
# Per Credit Fee: 6600
# Number of credits: 9
# ...
# Student Name: Adam, ID: 1234
# Fee: 119650
# DETAILS:
# Admission Fee: 28000
# Library Fee: 2000
# Semester Fee: 7700
# Per Credit Fee: 6600
# Number of credits: 12
# Lab Fee: 2750
# ...
# Student Name: David, ID: 121314
# Fee: 140000
# DETAILS:
# Admission Fee: 28000
# Library Fee: 2000
# Semester Fee: 11000
# Per Credit Fee: 6600
# Number of credits: 15
# ...
# Total Number of Students: 4
# Total University Revenue: 440100
# ...
# Due to the pandemic, admission and library fees have been reduced for all departments.
# The credit, semester and lab fees have been reduced for the CSE department.
# ...

# %%
OUTPUT:
================================
David, your tuition fee is 94500
================================
Name: David
Credit completed: 56
ID: 21336007
Course Details:
100 Level: ['PHY112', 'MAT110']
200 Level: ['PHY201', 'PHY270']
300 Level: ['CSE330']
================================
================================
Mike, your tuition fee is 75600
================================
Name: Mike
Credit completed: 32
ID: 21321168
Course Details:
100 Level: ['CSE110']
200 Level: ['EEE201']
400 Level: ['EEE480', 'EEE449']

# %%
class Student:
    def __init__(self, name, credit):
        self.name = name
        self.credit = credit

    def __str__(self):
            s = f"Name: {self.name}\nCredit completed: {self.credit}"
            return s

# Write your codes here.
# Do not change the following lines of code.
class MNSStudent(Student):
    def __init__(self, name, credit,id):
        super().__init__(name, credit)
        self.id=id
        self.dic={}
    def addCourses(self,*args):
        self.list=args
        for i in args:
            if i[2]==1:
                if "100 Level" not in self.dic.keys():
                    self.dic['100 Level']=[i]
                else:
                    self.dic['100 Level'].append(i)
            elif i[2]==2:
                if "200 Level" not in self.dic.keys():
                    self.dic['200 Level']=[i]
                else:
                    self.dic['200 Level'].append(i)
            elif i[3]==2:
                if "300 Level" not in self.dic.keys():
                    self.dic['300 Level']=[i]
                else:
                    self.dic['300 Level'].append(i)
        self.fee=len(args)*18900
    def showTuitionFee(self):
        print("david bhai neo",self.fee)
    def __str__(self):
        return 
            

s1 = MNSStudent("David", 56, 21336007)
s1.addCourses("PHY201","PHY112","PHY270","MAT110","CSE330")
print('====================================')
s1.showTuitionFee()
print('====================================')
print(s1)
print('====================================')
s2 = EEEStudent("Mike", 32, 21321168)
s2.addCourses("CSE110", "EEE201", "EEE480", "EEE449")
print('====================================')
s2.showTuitionFee()
print('====================================')
print(s2)
# Out:
# ...
# david bhai neo 94500
# ...
# Name: David
# Credit completed: 56
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e7761fdf1e96> in <module>
#      45 print(s1)
#      46 print('====================================')
# ---> 47 s2 = EEEStudent("Mike", 32, 21321168)
#      48 s2.addCourses("CSE110", "EEE201", "EEE480", "EEE449")
#      49 print('====================================')
#
# NameError: name 'EEEStudent' is not defined

# %%
class Student:
    def __init__(self, name, credit):
        self.name = name
        self.credit = credit
    def __str__(self):
        s = f"Name: {self.name}\nCredit completed: {self.credit}"
        return s
class MNSStudent(Student):
    def __init__(self,name,credit,id):
        super().__init__(name,credit)
        self.id=id
        self.dic={}
    def addCourses(self,*course):
        self.course=course
        for i in self.course:
            x=str(i[3])+str(00)+' Level:'
            if x not in self.dic:
                self.dic[x]=[i]
            else:
                self.dic[x].append(i)
    def showTuitionFee(self):
        print('{}, your tuition fee is {}'.format(self.name,(len(self.course)*18900)))
    def __str__(self):
        x=super().__str__()
        y='\nID'+str(self.id)+'\nCourse Details:\n'
        z=''
        for key,value in self.dic.items():
            z+=key
            a=''
            for i in value:
                a+=i+', '
        return x+y+z+a
s1 = MNSStudent("David", 56, 21336007)
s1.addCourses("PHY201","PHY112","PHY270","MAT110","CSE330")
print('====================================')
s1.showTuitionFee()
print('====================================')
print(s1)
print('====================================')
s2 = EEEStudent("Mike", 32, 21321168)
s2.addCourses("CSE110", "EEE201", "EEE480", "EEE449")
print('====================================')
s2.showTuitionFee()
print('====================================')
print(s2)
# Out:
# ...
# David, your tuition fee is 94500
# ...
# Name: David
# Credit completed: 56
# ID21336007
# Course Details:
# 20 Level:10 Level:30 Level:
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c183319d9a5a> in <module>
#      38 print(s1)
#      39 print('====================================')
# ---> 40 s2 = EEEStudent("Mike", 32, 21321168)
#      41 s2.addCourses("CSE110", "EEE201", "EEE480", "EEE449")
#      42 print('====================================')
#
# NameError: name 'EEEStudent' is not defined

# %%
OUTPUT:
1.------------------------------------
Naruto has been released in 2007!!!
2.------------------------------------
Anime Details:
Name: Naruto
Rating: 10
Genre: Adventure Fiction
Release Year: 2007
Characters:
Main: ['Naruto Uzumaki', 'Itachi Uchiha']
Anti Hero: ['Madara Uchiha']
Supporting: ['Pain', 'Shikamaru Nara']
3.====================================
4.------------------------------------
My Hero Academia has premiered 5 seasons!!!
5.------------------------------------
Anime Details:
Name: My Hero Academia
Rating: 8
Genre: Superhero Fiction
Season Premiered: 5
Characters:
Supporting: ['Uraraka', 'Mirio']
Anti Hero: ['Nomu']
Main: ['Midoriya', 'Todoroki']

# %%
class Anime:

    def __init__(self, name, rating, genre):


        self.name = name
        self.rating = rating
        self.genre = genre

    def add_character(self, *info):
        pass

    def __str__(self):
        s = f"Name: {self.name}\nRating: {self.rating}\nGenre: {self.genre}"
        return s

class Naruto(Anime):
    def __init__(self,name,rating,genre,year):
        super().__init__(name, rating, genre)
        self.year = year
    def add_character(self,*info):
        self.li={}
        for i in range(len(info)):
            if i%2!=0:
                if info[i] not in self.li.keys():
                    self.li[info[i]]=[info[i-1]]
                else:
                    self.li[info[i]].append(info[i-1])
        
    def release_year(self):
        print(f"{self.name} has been released in {self.year}!!!")
    def __str__(self):
        return f"{super().__str__()}\nRelease Year: {self.year}"
    

class MyHeroAcademia(Anime):
    def init(self,name,rating,genre,year):
        super().__init__(name, rating, genre)
        self.year = year
    def add_character(self,*info):
        self.li={}
        for i in range(len(info)):
            if i%2!=0:
                if info[i] not in self.li.keys():
                    self.li[info[i]]=[info[i-1]]
                else:
                    self.li[info[i]].append(info[i-1])
        
    def release_year(self):
        print(f"{self.name} has been released in {self.year}!!!")
    def __str__(self):
        return f"{super().__str__()}\nRelease Year: {self.year}"








naruto = Naruto("Naruto", 10, "Adventure Fiction", 2007)
naruto.add_character("Naruto Uzumaki", "Main", "Itachi Uchiha", "Main", "Madara Uchiha", "Anti Hero", "Pain", "Supporting", "Shikamaru Nara", "Supporting")
print('1.------------------------------------')
print(naruto.release_year())
print('2.------------------------------------')
print(naruto)
print('3.====================================')
my_hero_academia = MyHeroAcademia("My Hero Academia", 8, "Superhero Fiction", 5)
my_hero_academia.add_character("Supporting", "Uraraka", "Anti Hero", "Nomu", "Supporting", "Mirio", "Main", "Midoriya", "Main", "Todoroki")
print('4.------------------------------------')
print(my_hero_academia.season_status())
print('5.------------------------------------')
print(my_hero_academia)
# Out:
# 1.------------------------------------
# Naruto has been released in 2007!!!
# None
# 2.------------------------------------
# Name: Naruto
# Rating: 10
# Genre: Adventure Fiction
# Release Year: 2007
# 3.====================================
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-4b7bf441e8f0> in <module>
#      66 print(naruto)
#      67 print('3.====================================')
# ---> 68 my_hero_academia = MyHeroAcademia("My Hero Academia", 8, "Superhero Fiction", 5)
#      69 my_hero_academia.add_character("Supporting", "Uraraka", "Anti Hero", "Nomu", "Supporting", "Mirio", "Main", "Midoriya", "Main", "Todoroki")
#      70 print('4.------------------------------------')
#
# TypeError: __init__() takes 4 positional arguments but 5 were given
