# %% [markdown]
# Name: Shihab Muhtasim
#
# ID:21301610
#
# Sec:10
#
# Quiz 1
#
# CSE11

# %%
class ShoppingCart:
    def __init__(self,cartname=None):
        self.cartname=cartname
        self.count=0
        self.newlst=[]
    def addGadget(self,*item):
        if self.cartname==None:
            print('Please set the cart name first')
        else:
            self.item=item
            for i in self.item:
                if i not in self.newlst:
                    self.newlst.append(i)
    def setCartName(self,cartname):
        self.cartname=cartname
    def printCartDetails(self):
        print('Details of {} cart'.format(self.cartname))
        print('Total gadgets in the cart:',len(self.newlst))
        for i in self.newlst:
            print('Gadget'+i.stuff+' Model:'+i.name+' Price:'+str(i.price)+' Stock:'+str(i.amount)+' pcs')
    def removeFromCart(self,namenew):
        self.namenew=namenew
        if self.namenew not in self.item:
            print(self.namenew,'not found in cart!')
        else:
            self.newlst.remove(self.namenew)
class Product:
    def __init__(self,name,stuff,price,amount):
        self.lst=[]
        self.name=name
        self.stuff=stuff
        self.price=price
        self.amount=amount
        self.x='Gadget'+self.stuff+' Model:'+self.name+' Price:'+str(self.price)+' Stock:'+str(self.amount)+' pcs'
        self.lst.append(self.x)
s1 = ShoppingCart()
p1 = Product("Razer BlackShark","Headset",99.99,5)
p2 = Product("Razer Huntsman","Keyboard", 249.99,12)
print("1.====================================")
s1.addGadget(p1,p2)
print("2.====================================")
s1.setCartName("Amazon")
s1.addGadget(p1,p2)
s1.addGadget(Product("HyperX Fury", "Mousepad",26.99,21))
print("3.====================================")
s1.printCartDetails()
print("4.====================================")
s1.removeFromCart("Logitech G ProX Superlight")
print("5.====================================")
s1.removeFromCart("Razer Huntsman")
print("6.====================================")
s1.printCartDetails()
# Out:
# 1.====================================
# Please set the cart name first
# 2.====================================
# 3.====================================
# Details of Amazon cart
# Total gadgets in the cart: 3
# GadgetHeadset Model:Razer BlackShark Price:99.99 Stock:5 pcs
# GadgetKeyboard Model:Razer Huntsman Price:249.99 Stock:12 pcs
# GadgetMousepad Model:HyperX Fury Price:26.99 Stock:21 pcs
# 4.====================================
# Logitech G ProX Superlight not found in cart!
# 5.====================================
# Razer Huntsman not found in cart!
# 6.====================================
# Details of Amazon cart
# Total gadgets in the cart: 3
# GadgetHeadset Model:Razer BlackShark Price:99.99 Stock:5 pcs
# GadgetKeyboard Model:Razer Huntsman Price:249.99 Stock:12 pcs
# GadgetMousepad Model:HyperX Fury Price:26.99 Stock:21 pcs

# %%
class ShoppingCart:
    def __init__(self):
        self.gadgets = []
        self.cart_name = ""
    def addGadget(self, *gadgets):
        if(self.cart_name == ""):
            print("Please set the cart name first.")
        else:
            for gadget in gadgets:
                self.gadgets.append(gadget)                
    def setCartName(self, cart_name):
        self.cart_name = cart_name        
    def printCartDetails(self):
        print(f'Details of  {self.cart_name}  cart:')
        print(f'Total gadgets in cart: {str(len(self.gadgets))}')
        for gadget in self.gadgets:
            print(gadget)     
    def removeFromCart(self, model):
        flag = False        
        for gadget in self.gadgets:
            if gadget.model == model:
                self.gadgets.remove(gadget)
                flag = True
                break                
        if(flag):
            print(f'{model} removed from cart!')
        else:
            print(f'{model} not found in cart!')
        
class Product:
    totalProducts = 0
    def __init__(self, model, g_name, price, quantity):
        self.model = model
        self.g_name = g_name
        self.price = price
        self.quantity = quantity
        Product.totalProducts = Product.totalProducts + 1
    
    def createProduct(name, product, price, quantity):
        return Product(name, product, price, quantity)
    def __str__(self):
        return "Gadget:" + self.g_name + " Model:" + self.model + " Price:" + str(self.price) + "$ Stock:" + str(self.quantity) + " pcs";
 
s1 = ShoppingCart()
p1 = Product("Razer BlackShark","Headset",99.99,5)
p2 = Product("Razer Huntsman","Keyboard", 249.99,12)
print("1.====================================")
s1.addGadget(p1,p2)
print("2.====================================")
s1.setCartName("Amazon")
s1.addGadget(p1,p2)
s1.addGadget(Product("HyperX Fury", "Mousepad",26.99,21))
print("3.====================================")
s1.printCartDetails()
print("4.====================================")
s1.removeFromCart("Logitech G ProX Superlight")
print("5.====================================")
s1.removeFromCart("Razer Huntsman")
print("6.====================================")
s1.printCartDetails()
# Out:
# 1.====================================
# Please set the cart name first.
# 2.====================================
# 3.====================================
# Details of  Amazon  cart:
# Total gadgets in cart: 3
# Gadget:Headset Model:Razer BlackShark Price:99.99$ Stock:5 pcs
# Gadget:Keyboard Model:Razer Huntsman Price:249.99$ Stock:12 pcs
# Gadget:Mousepad Model:HyperX Fury Price:26.99$ Stock:21 pcs
# 4.====================================
# Logitech G ProX Superlight not found in cart!
# 5.====================================
# Razer Huntsman removed from cart!
# 6.====================================
# Details of  Amazon  cart:
# Total gadgets in cart: 2
# Gadget:Headset Model:Razer BlackShark Price:99.99$ Stock:5 pcs
# Gadget:Mousepad Model:HyperX Fury Price:26.99$ Stock:21 pcs

# %%
class ShoppingCart:
    def __init__(self):
        self.gadgets = []
        self.cart_name = ""
    def addGadget(self, *gadgets):
        if(self.cart_name == ""):
            print("Please set the cart name first.")
        else:
            for gadget in gadgets:
                print(gadget)
                self.gadgets.append(gadget)                
    def setCartName(self, cart_name):
        self.cart_name = cart_name        
    def printCartDetails(self):
        print(f'Details of  {self.cart_name}  cart:')
        print(f'Total gadgets in cart: {str(len(self.gadgets))}')
        for gadget in self.gadgets:
            print(gadget)     
    def removeFromCart(self, model):
        flag = False        
        for gadget in self.gadgets:
            if gadget.model == model:
                self.gadgets.remove(gadget)
                flag = True
                break                
        if(flag):
            print(f'{model} removed from cart!')
        else:
            print(f'{model} not found in cart!')
        
class Product:
    totalProducts = 0
    def __init__(self, model, g_name, price, quantity):
        self.model = model
        self.g_name = g_name
        self.price = price
        self.quantity = quantity
        Product.totalProducts = Product.totalProducts + 1
    
    def createProduct(name, product, price, quantity):
        return Product(name, product, price, quantity)
    def __str__(self):
        return "Gadget:" + self.g_name + " Model:" + self.model + " Price:" + str(self.price) + "$ Stock:" + str(self.quantity) + " pcs";
 
s1 = ShoppingCart()
p1 = Product("Razer BlackShark","Headset",99.99,5)
p2 = Product("Razer Huntsman","Keyboard", 249.99,12)
print("1.====================================")
s1.addGadget(p1,p2)
print("2.====================================")
s1.setCartName("Amazon")
s1.addGadget(p1,p2)
s1.addGadget(Product("HyperX Fury", "Mousepad",26.99,21))
print("3.====================================")
s1.printCartDetails()
print("4.====================================")
s1.removeFromCart("Logitech G ProX Superlight")
print("5.====================================")
s1.removeFromCart("Razer Huntsman")
print("6.====================================")
s1.printCartDetails()
# Out:
# 1.====================================
# Please set the cart name first.
# 2.====================================
# Gadget:Headset Model:Razer BlackShark Price:99.99$ Stock:5 pcs
# Gadget:Keyboard Model:Razer Huntsman Price:249.99$ Stock:12 pcs
# Gadget:Mousepad Model:HyperX Fury Price:26.99$ Stock:21 pcs
# 3.====================================
# Details of  Amazon  cart:
# Total gadgets in cart: 3
# Gadget:Headset Model:Razer BlackShark Price:99.99$ Stock:5 pcs
# Gadget:Keyboard Model:Razer Huntsman Price:249.99$ Stock:12 pcs
# Gadget:Mousepad Model:HyperX Fury Price:26.99$ Stock:21 pcs
# 4.====================================
# Logitech G ProX Superlight not found in cart!
# 5.====================================
# Razer Huntsman removed from cart!
# 6.====================================
# Details of  Amazon  cart:
# Total gadgets in cart: 2
# Gadget:Headset Model:Razer BlackShark Price:99.99$ Stock:5 pcs
# Gadget:Mousepad Model:HyperX Fury Price:26.99$ Stock:21 pcs

# %%
class ShoppingCart:
    def __init__(self):
        self.gadgets = []
        self.cart_name = ""
    def addGadget(self, *gadgets):
        if(self.cart_name == ""):
            print("Please set the cart name first.")
        else:
            for gadget in gadgets:
                self.gadgets.append(gadget)                
    def setCartName(self, cart_name):
        self.cart_name = cart_name        
    def printCartDetails(self):
        print(f'Details of  {self.cart_name}  cart:')
        print(f'Total gadgets in cart: {str(len(self.gadgets))}')
        for gadget in self.gadgets:
            print(gadget)     
    def removeFromCart(self, model):
        flag = False        
        for gadget in self.gadgets:
            if gadget.model == model:
                self.gadgets.remove(gadget)
                flag = True
                break                
        if(flag):
            print(f'{model} removed from cart!')
        else:
            print(f'{model} not found in cart!')
        
class Product:
    totalProducts = 0
    def __init__(self, model, g_name, price, quantity):
        self.model = model
        self.g_name = g_name
        self.price = price
        self.quantity = quantity
        Product.totalProducts = Product.totalProducts + 1
    
    def createProduct(name, product, price, quantity):
        return Product(name, product, price, quantity)
    def __str__(self):
        return "Gadget:" + self.g_name + " Model:" + self.model + " Price:" + str(self.price) + "$ Stock:" + str(self.quantity) + " pcs";
 
s1 = ShoppingCart()
p1 = Product("Razer BlackShark","Headset",99.99,5)
p2 = Product("Razer Huntsman","Keyboard", 249.99,12)
print("1.====================================")
s1.addGadget(p1,p2)
print("2.====================================")
s1.setCartName("Amazon")
s1.addGadget(p1,p2)
s1.addGadget(Product("HyperX Fury", "Mousepad",26.99,21))
print("3.====================================")
s1.printCartDetails()
print("4.====================================")
s1.removeFromCart("Logitech G ProX Superlight")
print("5.====================================")
s1.removeFromCart("Razer Huntsman")
print("6.====================================")
s1.printCartDetails()
# Out:
# 1.====================================
# Please set the cart name first.
# 2.====================================
# 3.====================================
# Details of  Amazon  cart:
# Total gadgets in cart: 3
# Gadget:Headset Model:Razer BlackShark Price:99.99$ Stock:5 pcs
# Gadget:Keyboard Model:Razer Huntsman Price:249.99$ Stock:12 pcs
# Gadget:Mousepad Model:HyperX Fury Price:26.99$ Stock:21 pcs
# 4.====================================
# Logitech G ProX Superlight not found in cart!
# 5.====================================
# Razer Huntsman removed from cart!
# 6.====================================
# Details of  Amazon  cart:
# Total gadgets in cart: 2
# Gadget:Headset Model:Razer BlackShark Price:99.99$ Stock:5 pcs
# Gadget:Mousepad Model:HyperX Fury Price:26.99$ Stock:21 pcs

# %%
Expected Output:
=================================
Mahmudullah added in team
=================================
Batsman:
Player name: Mahmudullah Jersey No: 30
=================================
=================================
Mustafizur Rahman added in team
A player cannot be added without a role.
=================================
Batsman:
Player name: Mahmudullah Jersey No: 30
Bowler:
Player name: Mustafizur Rahman Jersey No: 90
=================================
=================================
Tamim Iqbal added in team
=================================
Batsman:
Player name: Mahmudullah Jersey No: 30
Player name: Tamim Iqbal Jersey No: 28
Bowler:
Player name: Mustafizur Rahman Jersey No: 90
=================================
=================================
Mushfiqur Rahim added in team
Taskin Ahmed added in team
=================================
Batsman:
Player name: Mahmudullah Jersey No: 30
Player name: Tamim Iqbal Jersey No: 28
Player name: Mushfiqur Rahim Jersey No: 15
Bowler:
Player name: Mustafizur Rahman Jersey No: 90
Player name: Taskin Ahmed Jersey No: 3

# %%
class Player:
    def __init__(self,Player,position,jersey):
        self.player=Player
        self.position=position
        self.jersey=jersey
    def setRole(self,role):
        self.position=role



class Team:
    def __init__(self,name):
        self.name=name
    def addPlayer(self,*values):
        if type(self.position)!=str:
            print('A player cannot be added without a role.')
        else:
            print(f'{self.player} is added in team')
    def showPlayers(self):
        print(self.position,':')
        print(f'Player name: {self.player} Jersey No: {self.jersey}')

    
    
    
        
        

team = Team("Bangladesh")
p1 = Player("Mahmudullah", "Batsman",30)
print("=================================")
team.addPlayer(p1)
print("=================================")
team.showPlayers()
print("=================================")
p2 = Player("Mustafizur Rahman", "Bowler",90)
p3 = Player("Tamim Iqbal", 28)
print("=================================")
team.addPlayer(p2,p3)
print("=================================")
team.showPlayers()
print("=================================")
p3.setRole("Batsman")
print("=================================")
team.addPlayer(p3)
print("=================================")
team.showPlayers()
print("=================================")
p4 = Player("Mushfiqur Rahim", "Batsman",15)
p5 = Player("Taskin Ahmed", "Bowler",3)
print("=================================")
team.addPlayer(p4,p5)
print("=================================")
team.showPlayers()
# Out:
# =================================
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-5a3a6de89233> in <module>
#      28 p1 = Player("Mahmudullah", "Batsman",30)
#      29 print("=================================")
# ---> 30 team.addPlayer(p1)
#      31 print("=================================")
#      32 team.showPlayers()
#
# <ipython-input-20-5a3a6de89233> in addPlayer(self, *values)
#      11         self.name=name
#      12     def addPlayer(self,*values):
# ---> 13         if type(self.position)!=str:
#      14             print('A player cannot be added without a role.')
#      15         else:
#
# AttributeError: 'Team' object has no attribute 'position'
